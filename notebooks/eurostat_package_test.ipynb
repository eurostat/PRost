# %%
library("eurostat")

# %% [markdown]
# **Available R packages:**

# %%
lpack<-data.frame(unlist(library()))
npack<-nrow(lpack)/3 
packages<-c()
packages$name<-lpack[1:npack,1]
packages$description<-lpack[(2*npack+1):(3*npack),1]
data.frame(packages)
# Out:
#     name
# 1   abind
# 2   backports
# 3   BH
# 4   brew
# 5   broom
# 6   classInt
# 7   coda
# 8   crosstalk
# 9   curl
# 10  data.table
# 11  DBI
# 12  devtools
# 13  digest
# 14  eurostat
# 15  evaluate
# 16  gdtools
# 17  ggforce
# 18  ggiraph
# 19  ggnetwork
# 20  ggplot2
# 21  ggraph
# 22  ggrepel
# 23  ggTimeSeries
# 24  git2r
# 25  glue
# 26  gridExtra
# 27  hms
# 28  htmltools
# 29  htmlwidgets
# 30  httpuv
# ⋮   ⋮
# 156 withr
# 157 base
# 158 boot
# 159 class
# 160 cluster
# 161 codetools
# 162 compiler
# 163 datasets
# 164 foreign
# 165 graphics
# 166 grDevices
# 167 grid
# 168 KernSmooth
# 169 lattice
# 170 MASS
# 171 Matrix
# 172 methods
# 173 mgcv
# 174 nlme
# 175 nnet
# 176 parallel
# 177 rpart
# 178 spatial
# 179 splines
# 180 stats
# 181 stats4
# 182 survival
# 183 tcltk
# 184 tools
# 185 utils
#     description
# 1   Combine Multidimensional Arrays
# 2   Reimplementations of Functions Introduced Since R-3.0.0
# 3   Boost C++ Header Files
# 4   Templating Framework for Report Generation
# 5   Convert Statistical Analysis Objects into Tidy Tibbles
# 6   Choose Univariate Class Intervals
# 7   Output Analysis and Diagnostics for MCMC
# 8   Inter-Widget Interactivity for HTML Widgets
# 9   A Modern and Flexible Web Client for R
# 10  Extension of `data.frame`
# 11  R Database Interface
# 12  Tools to Make Developing R Packages Easier
# 13  Create Compact Hash Digests of R Objects
# 14  Tools for Eurostat Open Data
# 15  Parsing and Evaluation Tools that Provide More Details than the\nDefault
# 16  Utilities for Graphical Rendering
# 17  Accelerating 'ggplot2'
# 18  Make 'ggplot2' Graphics Interactive
# 19  Geometries to Plot Networks with 'ggplot2'
# 20  Create Elegant Data Visualisations Using the Grammar of Graphics
# 21  An Implementation of Grammar of Graphics for Graphs and Networks
# 22  Automatically Position Non-Overlapping Text Labels with\n'ggplot2'
# 23  Time Series Visualisations Using the Grammar of Graphics
# 24  Provides Access to Git Repositories
# 25  Interpreted String Literals
# 26  Miscellaneous Functions for "Grid" Graphics
# 27  Pretty Time of Day
# 28  Tools for HTML
# 29  HTML Widgets for R
# 30  HTTP and WebSocket Server Library
# ⋮   ⋮
# 156 Run Code 'With' Temporarily Modified Global State
# 157 The R Base Package
# 158 Bootstrap Functions (Originally by Angelo Canty for S)
# 159 Functions for Classification
# 160 "Finding Groups in Data": Cluster Analysis Extended Rousseeuw et\nal.
# 161 Code Analysis Tools for R
# 162 The R Compiler Package
# 163 The R Datasets Package
# 164 Read Data Stored by 'Minitab', 'S', 'SAS', 'SPSS', 'Stata',\n'Systat', 'Weka', 'dBase', ...
# 165 The R Graphics Package
# 166 The R Graphics Devices and Support for Colours and Fonts
# 167 The Grid Graphics Package
# 168 Functions for Kernel Smoothing Supporting Wand & Jones (1995)
# 169 Trellis Graphics for R
# 170 Support Functions and Datasets for Venables and Ripley's MASS
# 171 Sparse and Dense Matrix Classes and Methods
# 172 Formal Methods and Classes
# 173 Mixed GAM Computation Vehicle with Automatic Smoothness\nEstimation
# 174 Linear and Nonlinear Mixed Effects Models
# 175 Feed-Forward Neural Networks and Multinomial Log-Linear Models
# 176 Support for Parallel computation in R
# 177 Recursive Partitioning and Regression Trees
# 178 Functions for Kriging and Point Pattern Analysis
# 179 Regression Spline Functions and Classes
# 180 The R Stats Package
# 181 Statistical Functions using S4 Classes
# 182 Survival Analysis
# 183 Tcl/Tk Interface
# 184 Tools for Package Development
# 185 The R Utils Package
