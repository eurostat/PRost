# %%
library("eurostat")

# %%
get_eurostat("ilc_peps01")
# Out:
# Table ilc_peps01 cached at /tmp/RtmpUnfhHw/eurostat/ilc_peps01_date_code_TF.rds
#       unit    age    sex geo time       values
# 1     PC      TOTAL  F   AT  2017-01-01 19.3
# 2     PC      TOTAL  F   BE  2017-01-01 21.4
# 3     PC      TOTAL  F   BG  2017-01-01 40.4
# 4     PC      TOTAL  F   CZ  2017-01-01 13.9
# 5     PC      TOTAL  F   DK  2017-01-01 16.6
# 6     PC      TOTAL  F   EE  2017-01-01 25.6
# 7     PC      TOTAL  F   EL  2017-01-01 35.7
# 8     PC      TOTAL  F   ES  2017-01-01 27.1
# 9     PC      TOTAL  F   FI  2017-01-01 15.7
# 10    PC      TOTAL  F   HU  2017-01-01 26.1
# 11    PC      TOTAL  F   LV  2017-01-01 31.1
# 12    PC      TOTAL  F   MT  2017-01-01 20.1
# 13    PC      TOTAL  F   NL  2017-01-01 17.3
# 14    PC      TOTAL  F   NO  2017-01-01 17.0
# 15    PC      TOTAL  F   PL  2017-01-01 19.6
# 16    PC      TOTAL  F   PT  2017-01-01 24.0
# 17    PC      TOTAL  F   RO  2017-01-01 36.5
# 18    PC      TOTAL  F   SI  2017-01-01 18.3
# ...
