# %%
library("eurostat")
library("restatapi")
library("rdbnomics")
# Out:
# restatapi: The 'current' API version number is 1 and 7 cores are used for parallel computing.
#            Loaded config file with the API version number 1
#
#
# Attaching package: ‘restatapi’
#
# The following object is masked from ‘package:eurostat’:
#
#     get_eurostat_toc
#
# Visit <https://db.nomics.world>.

# %%
print(restatapi::get_eurostat_data("agr_r_milkpr",filters=c("BE$","Hungary"),date_filter=c(2015,"2008-01",2008:2010,"2016-01-01"),keep_flags=T))
eurostat::get_eurostat("agr_r_milkpr",filters=list(geo=c("BE","HU"),startDate=2008, endDate=2010),keepFlags=T)
# Out:
#     dairyprod milkitem geo time  values flags
#  1:    D1110A      PRO  BE 2015 3825.56  <NA>
#  2:    D1110A      PRO  HU 2015 1941.33  <NA>
#  3:    D1110A      PRO  BE 2008 3612.47     e
#  4:    D1110A      PRO  HU 2008 1840.49  <NA>
#  5:    D1110A      PRO  BE 2008 3612.47     e
#  6:    D1110A      PRO  HU 2008 1840.49  <NA>
#  7:    D1110A      PRO  BE 2009 3732.92     e
#  8:    D1110A      PRO  HU 2009 1758.22  <NA>
#  9:    D1110A      PRO  BE 2010 3873.21  <NA>
# 10:    D1110A      PRO  HU 2010 1684.92  <NA>
# 11:    D1110A      PRO  BE 2016 3894.57  <NA>
# 12:    D1110A      PRO  HU 2016 1918.23  <NA>
# Warning message in eurostat::get_eurostat("agr_r_milkpr", filters = list(geo = c("BE", :
# “keepFlags can be used only without filters. No Flags returned.”
#    milkitem dairyprod geo time       values
# 1  PRO      D1110A    BE  1995-01-01      NA
# 2  PRO      D1110A    BE  1996-01-01 3416.00
# 3  PRO      D1110A    BE  1997-01-01 3213.00
# ...

# %% [markdown]
# **Available R packages:**

# %%
lpack<-data.frame(unlist(library()))
npack<-nrow(lpack)/3 
packages<-c()
packages$name<-lpack[1:npack,1]
packages$description<-lpack[(2*npack+1):(3*npack),1]
print(data.frame(packages))
# Out:
#               name
# 1            abind
# 2        backports
# 3               BH
# 4             brew
# 5            broom
# 6         classInt
# 7             coda
# 8        crosstalk
# 9             curl
# 10      data.table
# 11             DBI
# 12        devtools
# 13          digest
# 14        eurostat
# 15        evaluate
# 16           flagr
# 17         gdtools
# 18         ggforce
# 19         ggiraph
# 20       ggnetwork
# 21         ggplot2
# 22          ggraph
# 23         ggrepel
# 24    ggTimeSeries
# 25           git2r
# 26            glue
# 27       gridExtra
# 28             hms
# 29       htmltools
# 30     htmlwidgets
# 31          httpuv
# 32            httr
# 33          igraph
# 34       IRdisplay
# 35        IRkernel
# 36           later
# 37         leaflet
# 38          lwgeom
# 39         mapview
# 40        markdown
# 41            mime
# 42         munsell
# 43         network
# 44         officer
# 45         openssl
# 46          pbdZMQ
# ...
